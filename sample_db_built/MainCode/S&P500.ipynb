# %%
# Import Dependencies
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Declares column types
from sqlalchemy import Column, Integer, Text, String, Float, Date

# %%
# Create Three_Bars
# ----------------------------------
class Three_Bars(Base):
    __tablename__ = 'threebars'
    index = Column(Integer, primary_key=True)
    quintile = Column(String(255))
    price_earnings = Column(Float)
    price_book = Column(Float)
    debt_equity = Column(Float)

# %%
# Create Five_lines
# ----------------------------------
class Five_Lines(Base):
    __tablename__ = 'fivelines'
    index = Column(Integer, primary_key=True)
    monthend = Column(Date)
    Q1 = Column(Float)
    Q2 = Column(Float)
    Q3 = Column(Float)
    Q4 = Column(Float)
    Q5 = Column(Float)

# %%
# Create Sample_Data
# ----------------------------------
class Sample_Data(Base):
    __tablename__ = 'sampledata'
    index = Column(Integer, primary_key=True)
    ticker = Column(String(255))
    date = Column(Date)
    threeMoRtn = Column(Float)
    price_earnings = Column(Float)
    price_book = Column(Float)
    debt_equity = Column(Float)
    capitalization = Column(Float)

# %%
# Create 3D_Chart
# ----------------------------------
class ThreeD_Chart(Base):
    __tablename__ = 'threedchart'
    index = Column(Integer, primary_key=True)
    quintile = Column(String(255))
    date = Column(Date)
    price_earnings = Column(Float)
    price_book = Column(Float)
    debt_equity = Column(Float)

# %%
three_bars_df = pd.read_csv('../DataSets/ThreeBars.csv')
three_bars_df
# Out:
#   quintile  price_earnings  price_book  debt_equity
# 0       Q1            12.3        11.4          7.5
# 1       Q2            10.4        12.5          4.8
# 2       Q3             8.6         9.1         13.5
# 3       Q4             7.5         8.6         12.1
# 4       Q5             3.8         4.7          8.8

# %%
five_lines_df = pd.read_csv('../DataSets/FiveLines.csv')
five_lines_df.head(5)
# Out:
#    monthend      Q1      Q2     Q3      Q4      Q5
# 0  12/31/14  1.0000  1.0000  1.000  1.0000  1.0000
# 1  01/31/15  1.0130  1.0090  1.002  0.9920  0.9900
# 2  02/28/15  1.0262  1.0150  1.005  0.9900  0.9751
# 3  03/31/15  1.0426  1.0181  1.008  0.9851  0.9673
# 4  04/30/15  1.0562  1.0222  1.014  0.9781  0.9607

# %%
sample_data_df = pd.read_csv('../DataSets/SampleData.csv')
sample_data_df.head(5)
# Out:
#   ticker      date  threeMoRtn  price_earnings  price_book  debt_equity  \
# 0    ABC  03/31/14        1.55           25.77       -0.26        97.62
# 1    ABC  06/30/14       12.87           25.57       -0.06        97.56
# 2    ABC  09/30/14      -11.06           25.10        0.07        98.78
# 3    ABC  12/31/14        0.96           25.84        0.27        98.27
# 4    ABC  03/31/15       19.05           24.39        0.56        98.38
#
#    capitalization
# 0       358647.00
# 1       358646.22
# 2       358645.63
# 3       358645.93
# 4       358646.85

# %%
three_dchart_df = pd.read_csv('../DataSets/3DChart.csv')
three_dchart_df.head(5)
# Out:
#   quintile      date  price_earnings  price_book  debt_equity
# 0       Q1  03/31/14            12.3        11.4          7.5
# 1       Q2  03/31/14            10.4        12.5          4.8
# 2       Q3  03/31/14             8.6         9.1         13.5
# 3       Q4  03/31/14             7.5         8.6         12.1
# 4       Q5  03/31/14             3.8         4.7          8.8

# %%
data_filename = "../DataSets/S&P500.sqlite"
engine = create_engine(f"sqlite:///{data_filename}", echo=False)
#conn = engine.connect()
Base.metadata.create_all(engine)

# %%
Base.metadata.tables
# Out:
# immutabledict({'threebars': Table('threebars', MetaData(bind=None), Column('index', Integer(), table=<threebars>, primary_key=True, nullable=False), Column('quintile', String(length=255), table=<threebars>), Column('price_earnings', Float(), table=<threebars>), Column('price_book', Float(), table=<threebars>), Column('debt_equity', Float(), table=<threebars>), schema=None), 'fivelines': Table('fivelines', MetaData(bind=None), Column('index', Integer(), table=<fivelines>, primary_key=True, nullable=False), Column('monthend', Date(), table=<fivelines>), Column('Q1', Float(), table=<fivelines>), Column('Q2', Float(), table=<fivelines>), Column('Q3', Float(), table=<fivelines>), Column('Q4', Float(), table=<fivelines>), Column('Q5', Float(), table=<fivelines>), schema=None), 'sampledata': Table('sampledata', MetaData(bind=None), Column('index', Integer(), table=<sampledata>, primary_key=True, nullable=False), Column('ticker', String(length=255), table=<sampledata>), Column('date', Date(), table=<sampledata>), Column('threeMoRtn', Float(), table=<sampledata>), Column('price_earnings', Float(), table=<sampledata>), Column('price_book', Float(), table=<sampledata>), Column('debt_equity', Float(), table=<sampledata>), Column('capitalization', Float(), table=<sampledata>), schema=None), 'threedchart': Table('threedchart', MetaData(bind=None), Column('index', Integer(), table=<threedchart>, primary_key=True, nullable=False), Column('quintile', String(length=255), table=<threedchart>), Column('date', Date(), table=<threedchart>), Column('price_earnings', Float(), table=<threedchart>), Column('price_book', Float(), table=<threedchart>), Column('debt_equity', Float(), table=<threedchart>), schema=None)})

# %%
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
three_bars_df.to_sql('threebars', con=engine, if_exists='append')
five_lines_df.to_sql('fivelines', con=engine, if_exists='append')
sample_data_df.to_sql('sampledata', con=engine, if_exists='append')
three_dchart_df.to_sql('threedchart', con=engine, if_exists='append')

# %%
engine.execute("SELECT price_earnings FROM threebars").fetchall()
# Out:
# [(12.3,), (10.4,), (8.6,), (7.5,), (3.8,)]

# %%
engine.execute("SELECT Q2 FROM fivelines").fetchall()
# Out:
# [(1.0,),
#  (1.0090000000000001,),
#  (1.015,),
#  (1.0181,),
#  (1.0222,),
#  (1.0243,),
#  (1.0244,),
#  (1.0306,),
#  (1.0367,),
#  (1.0419,),
#  (1.0441,),
#  (1.0453,),
#  (1.0486,),
#  (1.0568,),
#  (1.0661,),
#  (1.0674,),
#  (1.0768,),
#  (1.0871,),
#  (1.0916,),
#  (1.095,),
#  (1.1005,),
#  (1.102,),
#  (1.1095,),
#  (1.1111,),
#  (1.1146,),
#  (1.1212,),
#  (1.1298,),
#  (1.1304,),
#  (1.1361,),
#  (1.1388,),
#  (1.1435,),
#  (1.1512,),
#  (1.1519,),
#  (1.1527,),
#  (1.1585,),
#  (1.1663,),
#  (1.1731,),
#  (1.176,),
#  (1.1778,),
#  (1.1797,),
#  (1.1876,),
#  (1.1956,),
#  (1.2035,),
#  (1.2086,),
#  (1.2106,),
#  (1.2137,),
#  (1.2147,),
#  (1.2228,),
#  (1.2249,),
#  (1.232,),
#  (1.2402,),
#  (1.2444,),
#  (1.2486,),
#  (1.2499,),
#  (1.2601,),
#  (1.2674,),
#  (1.2778,)]

# %%
engine.execute("SELECT ticker FROM sampledata").fetchall()
# Out:
# [('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABC',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABD',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABE',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABF',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABG',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABH',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABI',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABJ',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABK',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABL',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABM',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABN',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABO',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABP',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABQ',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABR',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABS',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABT',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABU',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABV',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABW',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABX',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABY',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ABZ',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACA',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACB',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACC',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACD',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACE',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACF',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACG',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACH',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACI',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACJ',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACK',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACL',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACM',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACN',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACO',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACP',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACQ',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACR',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACS',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACT',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACU',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACV',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACW',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACX',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACY',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',),
#  ('ACZ',)]

# %%
engine.execute("SELECT quintile FROM threedchart").fetchall()
# Out:
# [('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',),
#  ('Q1',),
#  ('Q2',),
#  ('Q3',),
#  ('Q4',),
#  ('Q5',)]

# %%
three_bars_df.to_json()
# Out:
# '{"quintile":{"0":"Q1","1":"Q2","2":"Q3","3":"Q4","4":"Q5"},"price_earnings":{"0":12.3,"1":10.4,"2":8.6,"3":7.5,"4":3.8},"price_book":{"0":11.4,"1":12.5,"2":9.1,"3":8.6,"4":4.7},"debt_equity":{"0":7.5,"1":4.8,"2":13.5,"3":12.1,"4":8.8}}'

# %%
five_lines_df.to_json()
# Out:
# '{"monthend":{"0":"12\\/31\\/14","1":"01\\/31\\/15","2":"02\\/28\\/15","3":"03\\/31\\/15","4":"04\\/30\\/15","5":"05\\/31\\/15","6":"06\\/30\\/15","7":"07\\/31\\/15","8":"08\\/31\\/15","9":"09\\/30\\/15","10":"10\\/31\\/15","11":"11\\/30\\/15","12":"12\\/31\\/15","13":"01\\/31\\/16","14":"02\\/29\\/16","15":"03\\/31\\/16","16":"04\\/30\\/16","17":"05\\/31\\/16","18":"06\\/30\\/16","19":"07\\/31\\/16","20":"08\\/31\\/16","21":"09\\/30\\/16","22":"10\\/31\\/16","23":"11\\/30\\/16","24":"12\\/31\\/16","25":"01\\/31\\/17","26":"02\\/28\\/17","27":"03\\/31\\/17","28":"04\\/30\\/17","29":"05\\/31\\/17","30":"06\\/30\\/17","31":"07\\/31\\/17","32":"08\\/31\\/17","33":"09\\/30\\/17","34":"10\\/31\\/17","35":"11\\/30\\/17","36":"12\\/31\\/17","37":"01\\/31\\/18","38":"02\\/28\\/18","39":"03\\/31\\/18","40":"04\\/30\\/18","41":"05\\/31\\/18","42":"06\\/30\\/18","43":"07\\/31\\/18","44":"08\\/31\\/18","45":"09\\/30\\/18","46":"10\\/31\\/18","47":"11\\/30\\/18","48":"12\\/31\\/18","49":"01\\/31\\/19","50":"02\\/28\\/19","51":"03\\/31\\/19","52":